# %% [markdown]
# [![pythonista.io](img/pythonista.png)](https://www.pythonista.io)

# %% [markdown]
# # Lectura y escritura de archivos.
#
# *Python* tiene la capacidad de acceder y realizar operaciones de lectura/escritura sobre los documentos localizados en un sistema de archivos si el usuario cuenta con los permisos correspondientes.

# %% [markdown]
# ## Flujos de datos en sistemas basados en *UNIX*.
#
# Los sistemas *UNIX*, *MacOS X* y *GNU/Linux* se basan en la idea de que muchos recursos del sistema pueden representarse como flujos de datos o como archivos.
#
# Por ello es común interactuar con dispositivos o procesos mediante interfaces parecidas a las de un archivo. Ese tipo de accesos queda fuera del alcance de este curso introductorio.

# %% [markdown]
# ## Tamaño y posición de los archivos.
#
# Los archivos contienen una sucesión lineal de bytes o de caracteres.
#
# La posición de cada byte o carácter corresponde a un número entero no negativo iniciando a partir de ```0```.

# %% [markdown]
# ## Apertura de un archivo con la función ```open()```.
#
# La función ```open()``` permite interactuar con el sistema de archivos local para crear, escribir, leer o desplazarse dentro de un archivo de texto o binario.
#
# ```
# open(<ruta>, <modo>, encoding='utf-8')
# ```
#
# Donde:
#
# * ```<ruta>``` es un objeto de tipo ```str``` que indica la ruta en la que se encuentra el archivo.
# * ```<modo>``` es un objeto de tipo ```str``` que indica la forma en la que *Python* accederá al archivo en cuestión.
# * ```encoding``` es un parámetro que permite definir la codificación de un archivo de texto. Se recomienda utilizar siempre ```'utf-8'``` cuando el contenido incluya caracteres acentuados o símbolos especiales.
#
# **Notas:**
#
# * En Windows, las rutas suelen usar la diagonal invertida ```\```. Debido a que este carácter también se usa en secuencias de escape, es común escribirlo como ```\\``` dentro de una cadena.
# * Aunque es posible gestionar rutas usando cadenas de caracteres, se recomienda el uso del módulo ```pathlib```, el cual no se cubre en este curso.
# * Si no se define el argumento ```encoding``` en archivos de texto, *Python* utilizará la codificación por defecto del sistema operativo, lo que puede provocar comportamientos inesperados entre plataformas distintas.
# * El argumento ```encoding``` se usa con archivos de texto. En archivos binarios no corresponde indicar una codificación.

# %% [markdown]
# ### Modos de acceso a un archivo.

# %% [markdown]
# #### Por el tipo de acceso.
#
# * El carácter ```'r'``` indica que se accederá a un archivo exclusivamente para lectura y el apuntador se localizará en la posición ```0```. En caso de que el archivo no exista se desencadenará un error de tipo ```FileNotFoundError```.
# * El carácter ```'w'``` indica que se creará un archivo nuevo para escritura. En caso de que ya exista, su contenido será reemplazado.
# * El carácter ```'x'``` indica que se creará un archivo nuevo para escritura. En caso de que el archivo exista se emitirá un error de tipo ```FileExistsError```.
# * El carácter ```'a'``` indica que se accederá a un archivo para escritura. Si el archivo existe, el puntero se localizará al final. Si no existe, el archivo será creado.
# * Los caracteres ```'r+'``` indican que se accederá a un archivo para lectura y escritura sin truncarlo. El puntero se situará al inicio del archivo. En caso de que el archivo no exista se desencadenará un error de tipo ```FileNotFoundError```.

# %% [markdown]
# #### Por el tipo de archivo.
#
# Los archivos de texto y los archivos binarios representan dos tipos de objeto distintos en *Python*.
#
# * El carácter ```'t'``` indica que se trata de un archivo de texto. Este es el tipo de archivo que se usa por defecto.
# * El carácter ```'b'``` indica que se trata de un archivo binario. Se creará un objeto específico dependiendo del tipo de acceso.
#
#
# ### Tipos de objetos creados por ```open()```.
#
# La función ```open()``` puede crear objetos que permiten realizar operaciones de lectura y escritura de archivos.
#
# La siguiente tabla describe los tipos de objetos que se crearán dependiendo del tipo de archivo y del tipo de acceso del que se trate.

# %% [markdown]
# **Ejemplos:**
#
# * ```'wb'``` indica que se creará o sobreescribirá un archivo binario y se accederá en modo de escritura.
#
# * ```'a'``` indica que se accederá a un archivo de texto en modo de escritura. Si el archivo existe, el puntero se posicionará al final. Si el archivo no existe, será creado.
#
# * ```'rb+'``` indica que se accederá a un archivo binario en modo de lectura y escritura, situándose en la posición ```0``` del archivo.
#
# * ```'rt'``` indica que se accederá a un archivo de texto existente en modo de lectura, situándose en la posición ```0``` del archivo.

# %% [markdown]
# ### Tipos de objetos creados por ```open()```.
#
# La función ```open()``` puede crear objetos que permiten relizar las operaciones de lectura y escritura de archivos.
#
# La siguiente tabla describe los tipos de objetos que se crearán depenediendo del tipo de archivo y del tipo de acceso del que se trate.
#
# |Tipo de accesso|Texto|Binario|
# |:----------------:|:-------:|:---------:|
# |Lectura|```_io.TextIOWrapper```|```_io.BufferedReader```
# |Escritura|```_io.TextIOWrapper```|```_io.BufferedWriter```
# |Escritura/Lectura|```_io.TextIOWrapper```|```_io.BufferedRandom```

# %% [markdown]
# ## Atributos y métodos más utilizados para gestión de archivos comunes para archivos binarios y de texto.

# %% [markdown]
# ### El atributo ```mode```.
#
# Este atributo regresa un objeto de tipo ```str``` describiendo el modo de acceso al archivo.
#
# ```
# <objeto de archivo>.mode
# ```

# %% [markdown]
# ### El atributo ```name```.
#
# Este atributo regresa un objeto de tipo ```str``` con la ruta del archivo.
#
# ```
# <objeto de archivo>.name
# ```

# %% [markdown]
# ### El método ```close()```.
#
# Una vez terminadas las operaciones de entrada y salida, el archivo debe cerrarse de manera adecuada. Cerrar el archivo libera recursos del sistema y asegura que los datos pendientes en memoria intermedia se escriban correctamente.
#
# Aunque *Python* puede cerrar archivos al finalizar el programa, la práctica recomendada es cerrarlos explícitamente o usar la declaración ```with```.
#
# ```
# <objeto de archivo>.close()
# ```

# %% [markdown]
# ### El atributo ```closed```.
#
# Este atributo regresará un objeto de tipo ```bool```.
#
# * Regresará ```True``` si la conexión con el archivo está cerrada.
# * Regresará ```False``` si la conexión con el archivo sigue abierta.

# %% [markdown]
# ### El método ```writable()```.
#
# Este método valida si el archivo está habilitado para escritura, regresando un objeto de tipo ```bool```.
#
# * Regresará ```True``` si el archivo está en modo de escritura.
# * Regresará ```False``` si el archivo está exclusivamente en modo de lectura.
#
# ```
# <objeto de archivo>.writable()
# ```

# %% [markdown]
# ### El método ```readable()```.
#
# Este método valida si el archivo está habilitado para lectura, regresando un objeto de tipo ```bool```.
#
# * Regresará ```True``` si el archivo permite operaciones de lectura.
# * Regresará ```False``` si el archivo está abierto en un modo exclusivamente de escritura.
#
# ```
# <objeto de archivo>.readable()
# ```

# %% [markdown]
# ### El método ```seekable()```.
#
# Este método valida si es posible trasladarse a lo largo del archivo. Devolverá ```True``` si es posible desplazarse dentro del archivo.
#
# ```
# <objeto de archivo>.seekable()
# ```

# %% [markdown]
# ### El método ```tell()```.
#
# Regresará la posición en la que se encuentra el puntero dentro del archivo.
#
# ```
# <objeto de archivo>.tell()
# ```

# %% [markdown]
# ### El método ```seek()```.
#
# Moverá el puntero a la posición indicada.
#
# ```
# <objeto de archivo>.seek(<n>)
# ```
#
# Donde:
#
# * ```<n>``` es el índice dentro de un archivo en el que se posicionará el apuntador.

# %% [markdown]
# ### El método ```read()```.
#
# En caso de que el archivo se encuentre en modo de lectura, este método leerá y regresará su contenido a partir de la posición actual del puntero.
#
# * Si se ingresa un número entero como argumento:
#     * En archivos de texto leerá ese número de caracteres.
#     * En archivos binarios leerá ese número de bytes.
#     * Desplazará el puntero hasta la nueva posición alcanzada tras la lectura.
#     * Regresará el contenido leído.
#
# * Si no se ingresa un argumento:
#     * Leerá el archivo completo a partir de la posición en la que se encuentre.
#     * Desplazará el puntero hasta el final del archivo.
#     * Regresará el contenido leído.
#
# ```
# <objeto de archivo>.read(<n>)
# ```
#
# Donde:
#
# * ```<n>``` es la cantidad de caracteres o bytes que se leerán, dependiendo del tipo de archivo.

# %% [markdown]
# ### El método```readline()```.
#
# En caso de que el archivo se encuentre en modo de lectura, este método leerá y regresará el contenido que va desde la posición en la que se encuentra el puntero hasta encontrar un retorno de línea ```'\n'```. Cuando el puntero se encuentre al final del archivo (```EOF```), regresará un objeto de tipo ```str``` o ```bytes``` vacío.
#
# ```
# <objeto de archivo>.readline()
# ```

# %% [markdown]
# ### El método ```readlines()```.
#
# En caso de que el archivo se encuentre en modo de lectura, este método leerá el contenido desde la posición actual del puntero hasta el final del archivo y regresará un objeto de tipo ```list```.
#
# Cada elemento de esa lista corresponde a una línea del archivo y será un objeto de tipo ```str``` o ```bytes```, según el modo en el que se haya abierto el archivo.
#
# ```
# <objeto de archivo>.readlines()
# ```

# %% [markdown]
# ### El método ```write()```.
#
# Este método escribirá en el archivo en caso de que el archivo se encuentre en modo de escritura.
#
# ```
# <objeto de archivo>.write(<contenido>)
# ```
#
# * El contenido ingresado como argumento se escribirá partir de la posición en la que se encuentre el puntero.
# * El contenido ingresado como argumento sobreescribirá al texto existente.
# * Una vez terminada la operación, regresará la nueva posición del puntero.

# %% [markdown]
# ### El método ```writelines()```.
#
# En caso de que el archivo se encuentre en modo de escritura, este método escribirá desde la posición en la que se encuentre el puntero cada elemento de una colección uno después de otro.
#
# ```
# <objeto de archivo>.writelines(<colección>)
# ```
#
# Donde:
#
# * ```<colección>``` es una colección que contiene objetos de tipo ```str``` o ```bytes```.
#
# **Nota:** Este método no añade saltos de línea ```"\n"```.

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# * La siguiente celda regresará la posición actual del puntero en el archivo relacionado con el objeto ```mi_archivo```. El resultado será ```12```.

# %%
mi_archivo = open("prueba.bin", "wb")

# %% [markdown]
# * La siguiente celda regresará el tipo de objeto al que pertenece el objeto ```mi_archivo```. El resultado es ```_io.BufferedWriter```.

# %%
type(mi_archivo)

# %% [markdown]
# * La siguiente celda desplegará la posición en la que se encuentra el apuntador. Debido a que el archivo apenas fue creado, regresará  ```0```.

# %%
mi_archivo.tell()

# %% [markdown]
# * La siguiente celda verificará si el archivo ligado a ```mi_archivo``` está cerrado. El resultado será ```True```.

# %%
mi_archivo.write(b'Hola, mundo.')

# %% [markdown]
# * La siguiente celda validará si es posible mover el apuntador a lo largo del archivo relacionado al objeto ```mi_archivo```. El resultado será ```True```.

# %%
mi_archivo.seekable()

# %% [markdown]
# * La siguiete celda regresará la posición actual de puntero en el archivo relacionado al objeto ```mi_archivo```. El resultado será ```12```.

# %%
mi_archivo.tell()

# %% [markdown]
# * La siguiente celda regresará un objeto de tipo ```str``` indicando el modo de acceso usado. El resultado será ```'wb'```

# %%
mi_archivo.mode

# %% [markdown]
# * La siguiente celda regresará un objeto de tipo ```str``` contendiendo la ruta del archivo. El resultado será ```'prueba.bin'```

# %%
mi_archivo.name

# %% [markdown]
# * La siguiente celda cerrará la conexión entre el archivo ```prueba.bin``` y el objeto ```mi_archivo```.

# %%
mi_archivo.close()

# %% [markdown]
# * La siguiente celda verfificará si el archivo ligado a ```mi_archivo``` está abierto. El resutado será ```True```.

# %%
mi_archivo.closed

# %% [markdown]
# * Las siguientes celdas incluyen comandos del sistema operativo que desplegarán el contenido del archivo ```prueba.bin```.

# %% [markdown]
# * Para plataformas basadas en UNIX.

# %%
# !cat prueba.bin

# %% [markdown]
# * Para plataformas Windows.

# %%
# !type prueba.bin

# %% [markdown]
# * La siguiente celda abrirá el archivo ```prueba.bin``` en modo de lectura y creará el objeto ```lee_archivo```.

# %%
lee_archivo = open("prueba.bin", "rb")

# %% [markdown]
# * La siguiente celda regresará el tipo de objeto al que pertenece el objeto ```lee_archivo```. El resultado es ```_io.BufferedReader```.

# %%
type(lee_archivo)

# %% [markdown]
# * La siguiente celda regresará la posición del puntero. El resultado es ```0```.

# %%
lee_archivo.tell()

# %% [markdown]
# * La siguiente celda moverá el puntero a la posición ```5```.

# %%
lee_archivo.seek(5)

# %% [markdown]
# * La siguiente celda regresará el contenido desde la posición ```5``` hasta el final del archivo . El resultado es ```b' mundo.'```.

# %%
lee_archivo.read()

# %% [markdown]
# * La siguiente celda moverá el puntero a la posición ```0```.

# %%
lee_archivo.seek(0)

# %% [markdown]
# * La siguiente celda regresará 4 bytes del archivo desde la posición ```0```. El resultado es ```b'Hola'```.

# %%
lee_archivo.read(4)

# %% [markdown]
# * La siguiente celda cerrará la conexión entre el archivo ```prueba.bin``` y el objeto ```lee_archivo```.

# %%
lee_archivo.close()

# %% [markdown]
# ## La declaración ```with ```.
#
# La declaración ```with``` se utiliza con objetos que contienen un método ```close()```, permitiendo ejecutar el bloque de código que contiene, y que una vez ejecutado, ejecutrá el método ```close()``` del objeto.
#
# ```
# with open (<ruta>, <modo>) as <nombre>:
#     ...
#     ...
# ```
#
# Donde:
#
# * ```<ruta>``` es un objeto de tipo ```str``` que indica la ruta en la que se encuentra el archivo.
# * ```<modo>``` es un objeto de tipo ```str``` que indica la forma en la que *Python* accederá al archivo dado.
# * ```<nombre>``` es el nombre que se le asignará al objeto generado por ```open()```.

# %% [markdown]
# **Ejemplos:**

# %% [markdown]
# ## La declaración ```with ```.
#
# La declaración ```with``` se utiliza con objetos que administran recursos, como los archivos. Permite ejecutar un bloque de código y, al salir de él, cerrar el archivo automáticamente incluso si ocurre una excepción.
#
# ```
# with open(<ruta>, <modo>, encoding='utf-8') as <nombre>:
#     <bloque de código>
# ```
#
# Donde:
#
# * ```<ruta>``` es un objeto de tipo ```str``` que indica la ruta en la que se encuentra el archivo.
# * ```<modo>``` es un objeto de tipo ```str``` que indica la forma en la que *Python* accederá al archivo.
# * ```encoding``` se usa cuando se trabaja con archivos de texto.
# * ```<nombre>``` es la variable a la que se asignará el objeto de archivo dentro del bloque.

# %%
with open("prueba.txt", "w", encoding="utf-8") as archivo:
    archivo.writelines(["Hola.\n",
                        "Bienvenido al curso de Python.\n", 
                        "Esperamos que sea una agradable experiencia.\n"])
    print(archivo.tell())
    print(type(archivo))

# %% [markdown]
# * Las siguientes celdas incluyen comandos del sistema operativo que desplegarán el contenido del archivo ```prueba.txt```.

# %% [markdown]
# * Para plataformas basadas en UNIX.

# %%
# !cat prueba.txt

# %% [markdown]
# * Para la plataforma Windows.

# %%
# !type prueba.txt

# %% [markdown]
# * La siguiente celda realizará las siguientes acciones:
#     * Creará un  nuevo archivo de texto con el nombre ```prueba.txt``` en modo de lectura.
#     * Al objeto generado por ```open()``` se le asignará el nombre ```archivo```.
#     * Se leerá y desplegará la primera línea de texto, la cual corresponde a ```Hola```.
#     * Se leerán las siguientes líneas del documento y desplegará ```['Bienvenido al curso de Python.\n', 'Esperamos que sea una agradable experiencia.\n']```.
#     * Se cerrará el archivo.

# %%
with open("prueba.txt", "r", encoding="utf-8") as archivo:
    print(archivo.readline())
    print(archivo.readlines())

# %% [markdown]
# * La siguiente celda realizará las siguientes acciones:
#     * Creará un  nuevo archivo de texto con el nombre ```prueba.txt``` en modo de lectura.
#     * Al objeto generado por ```open()``` se le asignará el nombre ```archivo```.
#     * Se localizará el puntero en la posición ```12``` del archivo.
#     * Se leerán todas líneas a partir de dicha posición.
#     * Se desplegará cada línea.
#     * Se cerrará el archivo.

# %%
with open("prueba.txt", "r", encoding="utf-8") as archivo:
    archivo.seek(12)
    print(archivo.readlines())
    archivo.seek(0)
    for linea in archivo.readlines():
        print(linea)

# %% [markdown]
# * La siguiente celda realizará las siguientes acciones:
#     * Creará un  nuevo archivo de texto con el nombre ```prueba.txt``` en modo de inserción.
#     * Al objeto generado por ```open()``` se le asignará el nombre ```archivo```.
#     * Se desplegará la posición del puntero, correspondiente a ```85```.
#     * Se añadirán 2 líneas de texto ingresando ```("\nNueva linea.\nAqui \ty alla."``` como argumento del método ```archivo.write()```.
#     * Se desplegará la nueva posición del puntero, correspondiente a ```114```.
#     * Se cerrará el archivo.

# %%
with open("prueba.txt", "a", encoding="utf-8") as archivo:
    print(archivo.tell())
    archivo.write("\nNueva linea.\nAqui \ty alla.")
    print(archivo.tell())

# %% [markdown]
# * Las siguientes celdas incluyen comandos del sistema operativo que desplegarán el contenido del archivo ```prueba.txt```.

# %% [markdown]
# * Para plataformas basadas en UNIX.

# %%
# !cat prueba.txt

# %% [markdown]
# * Para plataformas Windows.

# %%
# !type prueba.txt

# %% [markdown]
# * La siguiente celda realizará las siguientes acciones:
#     * Creará un  nuevo archivo de texto con el nombre ```prueba.txt``` en modo de escritura/lectura.
#     * Al objeto generado por ```open()``` se le asignará el nombre ```archivo```.
#     * Se sobreescribirá el texto inicial ingresando ```"HOLA"``` como argumento del método ```archivo.write()```.
#     * Se posicionará al puntero al inicio del archivo.
#     * Se desplegará todo texto.
#     * Se cerrará el archivo.

# %%
with open("prueba.txt", "r+", encoding="utf-8") as archivo:
    archivo.write("HOLA")
    archivo.seek(0)
    print(archivo.read())

# %% [markdown]
# ## Iteraciones con archivos de texto.
#
# Cuando se utiliza un archivo de texto en modo de lectura dentro de una estructura ```for``` ... ```in```, *Python* va entregando una línea por iteración.
#
# Ese resultado es similar a recorrer la lista devuelta por ```readlines()```, pero iterar directamente sobre el archivo suele ser preferible porque no necesita cargar todas las líneas en memoria al mismo tiempo.

# %% [markdown]
# **Ejemplo:**

# %% [markdown]
# * Las siguientes celdas realizarán estas acciones:
#     * Abrirán el archivo ```prueba.txt``` en modo de lectura.
#     * Asignarán al objeto generado por ```open()``` el nombre ```archivo```.
#     * Desplegarán cada línea del archivo.
#     * Cerrarán el archivo al salir del bloque ```with```.
#
# * Ambas formas producen una salida equivalente, pero iterar directamente sobre el archivo suele ser más eficiente que usar ```readlines()``` cuando el archivo es grande.

# %%
with open("prueba.txt", "r", encoding="utf-8") as archivo:
    for linea in archivo:
        print(linea)

# %%
with open("prueba.txt", "r", encoding="utf-8") as archivo:
    for linea in archivo.readlines():
        print(linea)

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2017-2026.</p>
